# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('purchases4cohorts_betrag_structured-2.csv')
df['Rechnungsdatum'] = pd.to_datetime(df['Rechnungsdatum'])
df['KW'] = df["Rechnungsdatum"].dt.strftime('%U')
df['KW'] = df['KW'].astype('int64')

# %%
df.tail()
# Out:
#        user_id Rechnungsdatum  Betrag  KW
# 10756     4841     2024-04-15    50.0  15
# 10757     4842     2024-04-15    50.0  15
# 10758     4843     2024-04-15    50.0  15
# 10759     4844     2024-04-15    50.0  15
# 10760     4845     2024-04-15    50.0  15

# %%
df.describe()
# Out:
#             user_id                 Rechnungsdatum        Betrag            KW
# count  10761.000000                          10761  10761.000000  10761.000000
# mean    2067.904191  2024-03-03 04:18:48.073598976     51.337953      8.882818
# min        1.000000            2024-01-01 00:00:00     40.000000      0.000000
# 25%      953.000000            2024-02-12 00:00:00     49.550000      6.000000
# 50%     1930.000000            2024-03-04 00:00:00     50.000000      9.000000
# 75%     3118.000000            2024-04-01 00:00:00     51.370000     13.000000
# max     4845.000000            2024-04-15 00:00:00    107.860000     15.000000
# std     1314.659661                            NaN      8.692751      4.284116

# %%
df.dtypes
# Out:
# user_id                    int64
# Rechnungsdatum    datetime64[ns]
# Betrag                   float64
# KW                         int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.bar(fruits, sales)
plt.title('Fruit Sales')
plt.xlabel('Fruits')
plt.ylabel('Sales')
plt.show()
